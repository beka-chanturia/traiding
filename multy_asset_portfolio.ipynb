# %% [markdown]
# <a href="https://colab.research.google.com/github/beka-chanturia/traiding/blob/main/multy_asset_portfolio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install yfinance
# Out:
# Requirement already satisfied: yfinance in /usr/local/lib/python3.7/dist-packages (0.1.68)
# Requirement already satisfied: numpy>=1.15 in /usr/local/lib/python3.7/dist-packages (from yfinance) (1.19.5)
# Requirement already satisfied: lxml>=4.5.1 in /usr/local/lib/python3.7/dist-packages (from yfinance) (4.7.1)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.7/dist-packages (from yfinance) (1.1.5)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from yfinance) (0.0.10)
# Requirement already satisfied: requests>=2.26 in /usr/local/lib/python3.7/dist-packages (from yfinance) (2.26.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24->yfinance) (2.8.2)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24->yfinance) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.24->yfinance) (1.15.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (2.0.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (1.24.3)

# %%
import yfinance as yf
import datetime as dt
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn

# %%
symbols = ['GNRC' , 'DXCM' , 'AMD' , 'NFLX' , 'TGT' , 'AES']
df = yf.download(symbols, start='2018-01-01', end='2021-09-01')['Adj Close']
# Out:
# [*********************100%***********************]  6 of 6 completed

# %%
df[:3]
# Out:
#                  AES    AMD       DXCM       GNRC        NFLX        TGT
# Date
# 2018-01-02  9.545205  10.98  57.990002  48.029999  201.070007  61.324642
# 2018-01-03  9.536432  11.55  58.080002  49.730000  205.050003  60.907547
# 2018-01-04  9.501340  12.12  52.250000  50.070000  205.630005  59.710606

# %%
(df / df.iloc[0] * 100).plot(figsize=(16,9))

# %%
returns = np.log( df / df.shift(1))
mean_return = returns.mean() * 252
mean_return
# Out:
# AES     0.248872
# AMD     0.631621
# DXCM    0.604448
# GNRC    0.603505
# NFLX    0.284405
# TGT     0.379835
# dtype: float64

# %% [markdown]
# # **Covarience**

# %%
returns.cov() * 252
# Out:
#            AES       AMD      DXCM      GNRC      NFLX       TGT
# AES   0.144203  0.055266  0.043813  0.065557  0.032133  0.038466
# AMD   0.055266  0.312655  0.093411  0.086732  0.102382  0.057842
# DXCM  0.043813  0.093411  0.235140  0.060096  0.064031  0.030436
# GNRC  0.065557  0.086732  0.060096  0.158348  0.051556  0.041750
# NFLX  0.032133  0.102382  0.064031  0.051556  0.169375  0.031428
# TGT   0.038466  0.057842  0.030436  0.041750  0.031428  0.097915

# %% [markdown]
# # **Correlation**

# %%
corr_df = returns.corr()
corr_df
# Out:
#            AES       AMD      DXCM      GNRC      NFLX       TGT
# AES   1.000000  0.260278  0.237933  0.433836  0.205607  0.323713
# AMD   0.260278  1.000000  0.344512  0.389800  0.444906  0.330589
# DXCM  0.237933  0.344512  1.000000  0.311443  0.320851  0.200589
# GNRC  0.433836  0.389800  0.311443  1.000000  0.314808  0.335296
# NFLX  0.205607  0.444906  0.320851  0.314808  1.000000  0.244043
# TGT   0.323713  0.330589  0.200589  0.335296  0.244043  1.000000

# %% [markdown]
# # **Plot correlation matrix**

# %%
#სულ
plt.figure(figsize=(13,8))
seaborn.heatmap(corr_df, annot=True, cmap='RdYlGn')
plt.figure()

# %% [markdown]
# # **Generate random weights (sum=1)**
# ყველა კომპანიას ვანიჭებთ სათითაოდ სხვადასხვა წილებს. წონებს ვუცვლით და ვირჩევთ საუკეთესო შარფ რეიშოს

# %%
weights = np.random.random(len(symbols))
weights = weights / np.sum(weights)
print(weights)
print('')
print(sum(weights))
# Out:
# [0.18314648 0.01064219 0.23381972 0.2669726  0.09693416 0.20848485]
#
# 0.9999999999999998

# %% [markdown]
# # **Calculate return for portfolio**

# %%
np.sum(weights * returns.mean()) * 252
# Out:
# 0.4615114801207357

# %% [markdown]
# # **Calculate multyasset portfolio risk (standard deviation)**

# %%
np.sqrt(np.dot(weights.T, np.dot(returns.cov() * 252, weights )))
# Out:
# 0.2696355509690351

# %% [markdown]
# # **Analyzing returns and risks of 10,000 combinations**

# %%
p_ret = []
p_vol = []
p_SR = []
#sharp ratio
p_wt = []

for x in range(10000):
  # Generate random weights
  p_weights = np.random.random(len(symbols))
  p_weights = p_weights / np.sum(p_weights)

  #add weights uding those random weights
  ret_1 = np.sum(p_weights * returns.mean()) * 252
  p_ret.append(ret_1)

  #add volatility or standart deviation to list
  vol_1 = np.sqrt(np.dot(p_weights.T, np.dot(returns.cov() * 252, p_weights)))
  p_vol.append(vol_1)

  #get sharp ratio
  SR_1 = ret_1 / vol_1
  p_SR.append(SR_1)

  #store weights for each portfolio
  p_wt.append(p_weights)

#convert to Numpy array
p_ret = np.array(p_ret)
p_vol = np.array(p_vol)
p_SR = np.array(p_SR)
p_wt = np.array(p_wt)

# %% [markdown]
# # **Plot the efficient frontier**

# %%
#create dataframe with returnss and volatility
ports = pd.DataFrame({'Return': p_ret, 'Volatility': p_vol})

#volability - რისკი, return - უკუგება

ports.plot(x='Volatility', y='Return', kind='scatter', figsize=(13,8))

# %% [markdown]
# # **Find max sharp ratio**

# %%
#return the index of the largest sharp ratio
SR_idx = np.argmax(p_SR)

#find the ideal portfolio weights at that index
i = 0
while i < len(symbols):
  print('Stock : %s : %2.2f' % (symbols[i], (p_wt[SR_idx][i] * 100)))
  i += 1

#find returns of the portfolio
print ('\nReturn :', p_ret[SR_idx])

print('Volatility :', p_vol[SR_idx])

print('Sharp Ratio :', p_SR[SR_idx])
# Out:
# Stock : GNRC : 0.75
# Stock : DXCM : 5.05
# Stock : AMD : 26.71
# Stock : NFLX : 30.29
# Stock : TGT : 1.12
# Stock : AES : 36.07
#
# Return : 0.5182429679838298
# Volatility : 0.28054604281897133
# Sharp Ratio : 1.8472652929852154
